# %%
import math

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import math as mt

# %%
mt.sqrt(25)
# Out:
# 5.0

# %%
from numpy import random

# %%
import numpy as np

# %%
# uniform random numbers in [0,1]
dataOne = random.rand(5,5)

# %%
dataOne
# Out:
# array([[0.35534794, 0.81647749, 0.31549176, 0.4955564 , 0.20044086],
#        [0.63415992, 0.13879251, 0.19673428, 0.2931035 , 0.911013  ],
#        [0.04904154, 0.89175362, 0.19507443, 0.73870478, 0.62225027],
#        [0.08653832, 0.43878208, 0.93219129, 0.85705872, 0.69786225],
#        [0.8207899 , 0.61394995, 0.25886441, 0.22903618, 0.93058772]])

# %%
np.mean(dataOne)
# Out:
# 0.5087841249370786

# %%
print('I Love data Science')
# Out:
# I Love data Science

# %%
variableName = 25

# %%
variableName1 = 'I Love data Science'

# %%
print(variableName1)
# Out:
# I Love data Science

# %%
type(variableName)
# Out:
# int

# %%
varOne = 25

varTwo = 25.0

varThree = varOne + varTwo

print(varThree)
# Out:
# 50.0

# %%
list(varTwo)
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
str1 = str(varOne)
str2 = str(varTwo)
str3 = str1 + str2
print(str3)
# Out:
# 25Hello

# %%
listOne = [1,2,3,4]
print(listOne[1:3])
# Out:
# [2, 3]

# %%
tel = {'jack': 4098, 'sape': 4139}

# %%
tel['jack']
# Out:
# 4098

# %%
tel2 = {'Fonzie':1000, 'Emma':1001, 'Louisa':1002, 'Olivia':1003, 'Kirk':1004}
tel2['Kirk']
# Out:
# 1004

# %%
mt.fabs(tel2['Kirk'])
# Out:
# 1004.0

# %%
mt.sqrt(tel2['Fonzie'])
# Out:
# 31.622776601683793

# %%
tel2['Emma'] * tel2['Louisa']
# Out:
# 1003002

# %%
tel2['Olivia'] / tel2['Louisa']
# Out:
# 1.0009980039920159

# %%
tel2['Kirk'] - tel2['Emma']
# Out:
# 3

# %%
# %quickref

# %%
os.chdir('C:/Users/Family/Documents/Data Analytics/Course 5/Task 1')

# %%
# Find out your current working directory
import os
print(os.getcwd())
# Out: /Users/shane/Documents/blog
# Display all of the files found in your current working directory
print(os.listdir(os.getcwd()))
# Out:
# C:\Users\Family\Documents\Data Analytics\Course 5\Task 1
# ['C5T1 notes.docx', 'C5T1.pptx', 'default_credit.csv', '~$C5T1.pptx']

# %%
import csv

with open('default_credit.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(f'\t{row[0]} works in the {row[1]} department, and was born in {row[2]}.')
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are , X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X12, X13, X14, X15, X16, X17, X18, X19, X20, X21, X22, X23, Y
# 	ID works in the LIMIT_BAL department, and was born in SEX.
# 	1 works in the 20000 department, and was born in 2.
# 	2 works in the 120000 department, and was born in 2.
# 	3 works in the 90000 department, and was born in 2.
# 	4 works in the 50000 department, and was born in 2.
# 	5 works in the 50000 department, and was born in 1.
# 	6 works in the 50000 department, and was born in 1.
# 	7 works in the 500000 department, and was born in 1.
# 	8 works in the 100000 department, and was born in 2.
# 	9 works in the 140000 department, and was born in 2.
# 	10 works in the 20000 department, and was born in 1.
# 	11 works in the 200000 department, and was born in 2.
# 	12 works in the 260000 department, and was born in 2.
# 	13 works in the 630000 department, and was born in 2.
# 	14 works in the 70000 department, and was born in 1.
# ...

# %%
####### There were many lessons learned.  It is clear that just because you have a high level of comfort with R, it does not necessarily mean you will have smooth sailing learning Pyton.

###### Yes, the tutorial is a good method to start learning Python and I would recommend it to other begginers looking to learn Python.

###### It is important to take you time reading training materials and not assume other languages will behave exactly like Python.
